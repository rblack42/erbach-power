# %% [markdown]
# # McLean Duration Tree

# %%
# %reload_ext tikzmagic

# %%
# %%tikz
#
# \node {$t$}
#     child{ node {$\eta_{av}$}
#         child {node {F}}
#         child {node{$\eta_p$}}
#     }
#     child{node {E}
#         child{node{$k_m$}}
#         child{node{$w_m$}}
#     }
#     child{node {P}}
#     child {node {child 2}
#       child {node {A}}
#       child {node {B}}
#     };

# %%
# %%tikz -p tikz-qtree
#
# \tikzset{level distance=60pt}
# \Tree [.NP [.Adj tall ] [.N tree ] ]
# \end{tikzpicture}
# %
# \begin{tikzpicture}[sibling distance=72pt]
# \Tree [.$\eta_{av}$ [.Adj fat ] [.N tree ] ]
